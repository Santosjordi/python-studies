# %% [markdown]
# <a href="https://colab.research.google.com/github/Santosjordi/python-studies/blob/main/python-studies/sqlite-pandas/teste_etl_pandas_sqlite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ETL Usando Pandas
#
# https://pbpython.com/excel-file-combine.html
#
# ![Excel-File-Processing-pandas.png](data:image/png;base64,...)![Excel-File-Processing.png](data:image/png;base64,...)

# %%
# !ls '/content/drive/Shareddrives/Costura/FACCOES/FAC. JA/DATA REPOSITORY/EXTRATO ZMM045N'
# Out:
# 1421.XLSX  1521.XLSX  1621.XLSX  1721.XLSX

# %%
import pathlib
import glob

import numpy as np
import pandas as pd

path = '/content/drive/Shareddrives/Costura/FACCOES/FAC. JA/DATA REPOSITORY/EXTRATO ZMM045N/'
all_files = glob.glob(path + '*.XLSX')

all_data = pd.DataFrame()
for f in all_files:
    df = pd.read_excel(f)
    all_data = all_data.append(df,ignore_index=True)

all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66469 entries, 0 to 66468
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Categoria de estoque      56591 non-null  float64
#  1   Fornecedor                56591 non-null  float64
#  2   Nome Facção               56591 non-null  object
#  3   Material                  56591 non-null  float64
#  4   Período de Planejamento   2599 non-null   float64
#  5   Documento de compras      66465 non-null  float64
#  6   Data Criação Pedido       56591 non-null  datetime64[ns]
#  7   Dt.real mov.merc.         54161 non-null  datetime64[ns]
#  8   Descrição de nó           56537 non-null  object
#  9   Valor da matriz           56591 non-null  object
#  10  Quantidade                66469 non-null  int64
#  11  Tempo Minuto Pedido       66469 non-null  float64
#  12  Prox Operacao             10996 non-null  object
# ...
